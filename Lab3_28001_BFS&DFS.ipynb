# %% [markdown]
# <a href="https://colab.research.google.com/github/HarishBankai/SY-IAI/blob/main/Lab3_28001_BFS%26DFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import matplotlib.pyplot as plt

#BREADTH FIRST SEARCH
city_map = {
    "a": ["d", "c"],  # Root
    "d": ["b", "e"],  # Left Child of 'a' has its own children
    "c": [],          # Right Child of 'a' (Leaf node)
    "b": [],          # Leaf node
    "e": []           # Leaf node
}

G = nx.Graph(city_map)
nx.draw(G, with_labels=True)
plt.show()

# %%
from collections import deque

def bfs_city_traversal(city_map, start):
  visited = set()
  queue = deque([start])

  print("BFS TRANSVERSAL")

  while queue:
    intersection = queue.popleft()

    if intersection not in visited:
      print(intersection, end=" ")

      visited.add(intersection)

      for neighbor in city_map[intersection]:
        if neighbor not in visited:
          queue.append(neighbor)

# %%
bfs_city_traversal(city_map, "a")
# Out:
# BFS TRANSVERSAL
# a d c b e

# %%
def dfs_city_traversal(city_map, start, visited=None):
    if visited is None:
        visited = set()

    print(start, end=" ")
    visited.add(start)

    for neighbor in city_map[start]:
        if neighbor not in visited:
            dfs_city_traversal(city_map, neighbor, visited)

# %%
dfs_city_traversal(city_map, "a")
# Out:
# a d b e c

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-968629041.py in <cell line: 0>()
# ----> 1 dfs_city_traversal(city_map, "a")
#
# NameError: name 'dfs_city_traversal' is not defined
