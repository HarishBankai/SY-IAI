# %% [markdown]
# <a href="https://colab.research.google.com/github/HarishBankai/SY-IAI/blob/main/SY_IAI_28001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

A = np.array([[2, -1] ,
              [-1, 2]])

if (A == A.T).all():
  print("A is symmetric")
else:
  print("A is not symmetric")
# Out:
# A is symmetric

# %%
import numpy as np

A = np.array([[2, -1] ,
              [-1, 2]])

is_symmetric = True
for i in range(2):
  for j in range(2):
    if A[i, j] != A[j,i]:
      is_symmetric = False
      break
      if not is_symmetric:
        breaK

if is_symmetric:
  print("A is symmetric")
else:
  print("A is not symmetric")
# Out:
# A is symmetric

# %%
import numpy as np

n=int(input("Enter the size of the matrix: "))

A = np.zeros((n, n), dtype=int) # Initialize the matrix A 56 with zeros

for i in range(n):
  for j in range(n):
    A[i,j] = int(input(f"Enter element {i}{j} : ")) # element prompt with position number

is_symmetric = True
for i in range(n):
  for j in range(n):
    if A[i, j] != A[j,i]:
      is_symmetric = False
      break
  if not is_symmetric:
    break

if is_symmetric:
  print("A is symmetric")
else:
  print("A is not symmetric")
# Out:
# Enter the size of the matrix: 2
# Enter element 00 : 2
# Enter element 01 : -1
# Enter element 10 : -1
# Enter element 11 : 2
# A is symmetric
